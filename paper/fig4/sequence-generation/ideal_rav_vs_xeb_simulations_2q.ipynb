# %%
from datetime import datetime
import numpy as np
import matplotlib.pyplot as plt
import os
import pickleslicer
from stoqcompiler.unitary import *
from stoqcompiler.verification import *

import jaqalpaq
from jaqalpaq.parser import parse_jaqal_string
from jaqalpaq.emulator import run_jaqal_circuit
from jaqalpaq.generator import generate_jaqal_program
from qscout.v1.native_gates import U_R, U_MS, U_Rz

# %% [markdown]
# ## Define the 2-qubit system parameters

# %%
num_system_qubits = 2

qubit_dimension = 2
system_dimension = qubit_dimension ** num_system_qubits
qubits_to_use = [q for q in range(num_system_qubits)]

def qscout_r(max_angle):
    min_value = -max_angle
    max_value = max_angle
    parameters = [ParameterizedUnitaryParameter("Φ", -np.pi, np.pi, is_angle=True),
                  ParameterizedUnitaryParameter("θ", min_value, max_value, is_angle=True)]
    operation_name = "R"
    connectivity = [[q] for q in range(num_system_qubits)]
    allowed_apply_to = [apply_to for apply_to in connectivity if set(apply_to).issubset(set(qubits_to_use))]
    return UnitaryPrimitive(ParameterizedUnitary(qubit_dimension, U_R, parameters, operation_name), allowed_apply_to)

def qscout_rz(max_angle):
    min_value = -max_angle
    max_value = max_angle
    parameters = [ParameterizedUnitaryParameter("θ", min_value, max_value, is_angle=True)]
    operation_name = "Rz"
    connectivity = [[q] for q in range(num_system_qubits)]
    allowed_apply_to = [apply_to for apply_to in connectivity if set(apply_to).issubset(set(qubits_to_use))]
    return UnitaryPrimitive(ParameterizedUnitary(qubit_dimension, U_Rz, parameters, operation_name), allowed_apply_to)

def qscout_ms(max_angle):
    min_value = -max_angle
    max_value = max_angle
    dimension = 2
    parameters = [ParameterizedUnitaryParameter("Φ", -np.pi, np.pi, is_angle=True),
                  ParameterizedUnitaryParameter("θ", min_value, max_value, is_angle=True)]
    operation_name = "MS"
    connectivity = [[i,j] for i in range(num_system_qubits) for j in range(num_system_qubits) if i != j]
    allowed_apply_to = [apply_to for apply_to in connectivity if set(apply_to).issubset(set(qubits_to_use))]
    return UnitaryPrimitive(ParameterizedUnitary(qubit_dimension ** 2, U_MS, parameters, operation_name), allowed_apply_to)

# %% [markdown]
# ## How RAV uncertainty scales with # of shots
#
# - Choose a representative long-enough random RAV circuit with ideal output state $\lvert\psi\rangle \approx \sqrt{1-\epsilon} \lvert0\rangle + \sqrt{\epsilon} \lvert\textrm{other states}\rangle$
# - Plot a whole bunch of points, x-axis = # shots, y-axis = initial state probability, for:
#    - 100% ideal output state $2^n \cdot \rho = \lvert\psi\rangle\langle\psi\rvert$
#    - 75% ideal output state $2^n \cdot \rho = \frac{3}{4} \lvert\psi\rangle\langle\psi\rvert + \frac{1}{4} I$
#    - 50% ideal output state $2^n \cdot \rho = \frac{1}{2} \lvert\psi\rangle\langle\psi\rvert + \frac{1}{2} I$
#    - 25% ideal output state $2^n \cdot \rho = \frac{1}{4} \lvert\psi\rangle\langle\psi\rvert + \frac{3}{4} I$
#    - completely mixed output state $2^n \cdot \rho = I$

# %%
unitary_primitive_counts = {
    qscout_r(max_angle=np.pi/10): 3,
    qscout_rz(max_angle=np.pi/10): 3,
    qscout_ms(max_angle=np.pi/10): 1
}

timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
directory = f"output_ideal_rav_vs_xeb_simulations/{timestamp}"
if not os.path.exists(directory):
    os.makedirs(directory)

# %%
sequence_count = 20
layer_count = 10

rav_results = []
for seq_idx in range(sequence_count):
    final_cost = 1.0
    while final_cost > 0.02:
        rav_result = Verification.generate_layered_rav_sequence(
            system_dimension,
            unitary_primitive_counts,
            layer_count,
            max_step_count = 4000,
            threshold = 1.0,
        )

        product = rav_result.compiled_sequence.product()
        identity = Unitary.identity(system_dimension)
        final_cost = product.distance_from(identity)

        print(f"generated circuit: length {rav_result.compiled_sequence.get_length()} with final cost {final_cost}")

    rav_results.append(rav_result)
    filename = f'{directory}/rav_{num_system_qubits}q_{layer_count}_{seq_idx}.txt'
    with open(filename, 'w') as f:
        f.write(f'''
    from qscout.v1.std usepulses *
    register q[{len(qubits_to_use)}]
    prepare_all
    ''')
        f.write(rav_result.compiled_sequence.get_jaqal())
        f.write(f'''
    measure_all
    ''')

    print(f"SUCCESS: wrote JAQAL circuit to {filename}")
# Out:
# generated circuit: length 98 with final cost 0.015468345682859375
# SUCCESS: wrote JAQAL circuit to output_ideal_rav_vs_xeb_simulations/20220417_131316/rav_2q_10_0.txt
# generated circuit: length 147 with final cost 0.02340908433017408
# generated circuit: length 126 with final cost 0.046098932171655504
# generated circuit: length 133 with final cost 0.021460876643882743
# generated circuit: length 119 with final cost 0.032849005221280425
# generated circuit: length 105 with final cost 0.009953105663584871
# SUCCESS: wrote JAQAL circuit to output_ideal_rav_vs_xeb_simulations/20220417_131316/rav_2q_10_1.txt
# generated circuit: length 126 with final cost 0.01931528403832461
# SUCCESS: wrote JAQAL circuit to output_ideal_rav_vs_xeb_simulations/20220417_131316/rav_2q_10_2.txt
# generated circuit: length 126 with final cost 0.03849304873921888
# generated circuit: length 259 with final cost 0.02229114410099342
# generated circuit: length 245 with final cost 0.014118604203333995
# SUCCESS: wrote JAQAL circuit to output_ideal_rav_vs_xeb_simulations/20220417_131316/rav_2q_10_3.txt
# generated circuit: length 154 with final cost 0.02315154861994162
# generated circuit: length 210 with final cost 0.023873809091123466
# generated circuit: length 133 with final cost 0.024254771535693664
# generated circuit: length 140 with final cost 0.02050554515967118
# generated circuit: length 210 with final cost 0.012616148713417763
# SUCCESS: wrote JAQAL circuit to output_ideal_rav_vs_xeb_simulations/20220417_131316/rav_2q_10_4.txt
# generated circuit: length 77 with final cost 0.04747792859117006
# generated circuit: length 217 with final cost 0.017974154767288475
# SUCCESS: wrote JAQAL circuit to output_ideal_rav_vs_xeb_simulations/20220417_131316/rav_2q_10_5.txt
# generated circuit: length 140 with final cost 0.021840720932048252
# generated circuit: length 98 with final cost 0.03146366058154071
# generated circuit: length 112 with final cost 0.010202864410069457
# SUCCESS: wrote JAQAL circuit to output_ideal_rav_vs_xeb_simulations/20220417_131316/rav_2q_10_6.txt
# generated circuit: length 231 with final cost 0.03214383325716563
# generated circuit: length 119 with final cost 0.0111303721897823
# SUCCESS: wrote JAQAL circuit to output_ideal_rav_vs_xeb_simulations/20220417_131316/rav_2q_10_7.txt
# generated circuit: length 182 with final cost 0.01991833284931599
# SUCCESS: wrote JAQAL circuit to output_ideal_rav_vs_xeb_simulations/20220417_131316/rav_2q_10_8.txt
# generated circuit: length 217 with final cost 0.02798513268690106
# generated circuit: length 161 with final cost 0.01820711517871365
# SUCCESS: wrote JAQAL circuit to output_ideal_rav_vs_xeb_simulations/20220417_131316/rav_2q_10_9.txt
# generated circuit: length 252 with final cost 0.05593914037150394
# generated circuit: length 105 with final cost 0.059251597185039806
# generated circuit: length 119 with final cost 0.026568064697238936
# generated circuit: length 238 with final cost 0.013263784894779751
# SUCCESS: wrote JAQAL circuit to output_ideal_rav_vs_xeb_simulations/20220417_131316/rav_2q_10_10.txt
# generated circuit: length 266 with final cost 0.011676828556559271
# SUCCESS: wrote JAQAL circuit to output_ideal_rav_vs_xeb_simulations/20220417_131316/rav_2q_10_11.txt
# generated circuit: length 119 with final cost 0.00977978804433377
# SUCCESS: wrote JAQAL circuit to output_ideal_rav_vs_xeb_simulations/20220417_131316/rav_2q_10_12.txt
# generated circuit: length 119 with final cost 0.017352106763505737
# SUCCESS: wrote JAQAL circuit to output_ideal_rav_vs_xeb_simulations/20220417_131316/rav_2q_10_13.txt
# generated circuit: length 182 with final cost 0.02747418044063399
# generated circuit: length 231 with final cost 0.020458855418992727
# generated circuit: length 161 with final cost 0.014236170308435048
# SUCCESS: wrote JAQAL circuit to output_ideal_rav_vs_xeb_simulations/20220417_131316/rav_2q_10_14.txt
# generated circuit: length 231 with final cost 0.025345409517399498
# generated circuit: length 84 with final cost 0.03174567714828236
# generated circuit: length 126 with final cost 0.02077317451591354
# generated circuit: length 245 with final cost 0.024073379234729297
# generated circuit: length 210 with final cost 0.02907682508694509
# generated circuit: length 259 with final cost 0.04201366597236078
# generated circuit: length 91 with final cost 0.03504340979132148
# generated circuit: length 140 with final cost 0.02603543570807465
# generated circuit: length 154 with final cost 0.014106752848373705
# SUCCESS: wrote JAQAL circuit to output_ideal_rav_vs_xeb_simulations/20220417_131316/rav_2q_10_15.txt
# generated circuit: length 105 with final cost 0.029972810052678933
# generated circuit: length 154 with final cost 0.024925619013351996
# generated circuit: length 119 with final cost 0.03665092087917243
# generated circuit: length 161 with final cost 0.02454276040616732
# generated circuit: length 91 with final cost 0.018717386582782103
# SUCCESS: wrote JAQAL circuit to output_ideal_rav_vs_xeb_simulations/20220417_131316/rav_2q_10_16.txt
# generated circuit: length 126 with final cost 0.015712900865493484
# SUCCESS: wrote JAQAL circuit to output_ideal_rav_vs_xeb_simulations/20220417_131316/rav_2q_10_17.txt
# generated circuit: length 98 with final cost 0.016305642586537217
# SUCCESS: wrote JAQAL circuit to output_ideal_rav_vs_xeb_simulations/20220417_131316/rav_2q_10_18.txt
# generated circuit: length 273 with final cost 0.016280535073967983
# SUCCESS: wrote JAQAL circuit to output_ideal_rav_vs_xeb_simulations/20220417_131316/rav_2q_10_19.txt

# %%
rav_x_data = {}
rav_y_data = {}    
for seq_idx, rav_result in enumerate(rav_results):
    rav_sequence_matrix = rav_result.compiled_sequence.product().get_matrix()

    mixed_state_fraction_list = [0.0, 0.25, 0.5, 0.75, 1.0]

    rav_x_data[seq_idx] = {}
    rav_y_data[seq_idx] = {}

    for i, mixed_state_fraction in enumerate(mixed_state_fraction_list):
        initial_state_index = 1

        # calculate the ideal output state
        initial_state = np.zeros(system_dimension)
        initial_state[initial_state_index] = 1
        initial_state = np.atleast_2d(initial_state).T
        ideal_output_state = rav_sequence_matrix @ initial_state
        #print("ideal_output_state coefficients:", np.round(ideal_output_state.T, 4))

        # validate the state
        ideal_output_probs = np.array([np.linalg.norm(c)**2 for c in ideal_output_state])
        #print("ideal_output_probs =", np.round(ideal_output_probs, 4))
        sum_of_probs = np.sum([np.linalg.norm(c)**2 for c in ideal_output_state])
        assert np.isclose(sum_of_probs, 1.0)

        # mix in the mixed state fraction
        mixed_state_output_probs = np.array([1/system_dimension for _ in range(system_dimension)])
        output_probs = np.add(
            (1-mixed_state_fraction) * ideal_output_probs,
            mixed_state_fraction * mixed_state_output_probs
        )
        print(f"mixed_state_fraction = {mixed_state_fraction}, output_probs = {np.round(output_probs, 4)}")

        # sample many times and plot
        n_shots_list = [25, 50, 100, 200, 400, 800, 1600, 3200, 6400]
        repetitions = 100
        rav_x_data[seq_idx][mixed_state_fraction] = []
        rav_y_data[seq_idx][mixed_state_fraction] = []
        for n_shots in n_shots_list:
            for _ in range(repetitions):
                measurements = [int(np.random.random() < output_probs[initial_state_index]) for _ in range(n_shots)]
                scaled_fidelity = (np.mean(measurements) - 1/system_dimension) * (system_dimension/(system_dimension-1))

                rav_x_data[seq_idx][mixed_state_fraction].append(n_shots)
                rav_y_data[seq_idx][mixed_state_fraction].append(scaled_fidelity)
# Out:
# mixed_state_fraction = 0.0, output_probs = [0.0031 0.9535 0.0161 0.0274]
# mixed_state_fraction = 0.25, output_probs = [0.0648 0.7776 0.0746 0.083 ]
# mixed_state_fraction = 0.5, output_probs = [0.1265 0.6017 0.133  0.1387]
# mixed_state_fraction = 0.75, output_probs = [0.1883 0.4259 0.1915 0.1943]
# mixed_state_fraction = 1.0, output_probs = [0.25 0.25 0.25 0.25]
# mixed_state_fraction = 0.0, output_probs = [0.0038 0.9717 0.001  0.0235]
# mixed_state_fraction = 0.25, output_probs = [0.0654 0.7913 0.0633 0.0801]
# mixed_state_fraction = 0.5, output_probs = [0.1269 0.6108 0.1255 0.1367]
# mixed_state_fraction = 0.75, output_probs = [0.1885 0.4304 0.1878 0.1934]
# mixed_state_fraction = 1.0, output_probs = [0.25 0.25 0.25 0.25]
# mixed_state_fraction = 0.0, output_probs = [1.140e-02 9.764e-01 2.000e-04 1.200e-02]
# mixed_state_fraction = 0.25, output_probs = [0.0711 0.7948 0.0626 0.0715]
# mixed_state_fraction = 0.5, output_probs = [0.1307 0.6132 0.1251 0.131 ]
# mixed_state_fraction = 0.75, output_probs = [0.1904 0.4316 0.1875 0.1905]
# mixed_state_fraction = 1.0, output_probs = [0.25 0.25 0.25 0.25]
# mixed_state_fraction = 0.0, output_probs = [0.026  0.9505 0.021  0.0024]
# mixed_state_fraction = 0.25, output_probs = [0.082  0.7754 0.0783 0.0643]
# mixed_state_fraction = 0.5, output_probs = [0.138  0.6003 0.1355 0.1262]
# mixed_state_fraction = 0.75, output_probs = [0.194  0.4251 0.1928 0.1881]
# mixed_state_fraction = 1.0, output_probs = [0.25 0.25 0.25 0.25]
# mixed_state_fraction = 0.0, output_probs = [0.0089 0.9803 0.0065 0.0043]
# mixed_state_fraction = 0.25, output_probs = [0.0692 0.7977 0.0673 0.0657]
# mixed_state_fraction = 0.5, output_probs = [0.1295 0.6152 0.1282 0.1272]
# mixed_state_fraction = 0.75, output_probs = [0.1897 0.4326 0.1891 0.1886]
# mixed_state_fraction = 1.0, output_probs = [0.25 0.25 0.25 0.25]
# mixed_state_fraction = 0.0, output_probs = [0.0078 0.9626 0.0084 0.0212]
# mixed_state_fraction = 0.25, output_probs = [0.0684 0.7844 0.0688 0.0784]
# mixed_state_fraction = 0.5, output_probs = [0.1289 0.6063 0.1292 0.1356]
# mixed_state_fraction = 0.75, output_probs = [0.1895 0.4281 0.1896 0.1928]
# mixed_state_fraction = 1.0, output_probs = [0.25 0.25 0.25 0.25]
# mixed_state_fraction = 0.0, output_probs = [9.000e-04 9.772e-01 1.290e-02 9.000e-03]
# mixed_state_fraction = 0.25, output_probs = [0.0632 0.7954 0.0722 0.0693]
# mixed_state_fraction = 0.5, output_probs = [0.1254 0.6136 0.1315 0.1295]
# mixed_state_fraction = 0.75, output_probs = [0.1877 0.4318 0.1907 0.1898]
# mixed_state_fraction = 1.0, output_probs = [0.25 0.25 0.25 0.25]
# mixed_state_fraction = 0.0, output_probs = [0.0039 0.9823 0.0121 0.0017]
# mixed_state_fraction = 0.25, output_probs = [0.0654 0.7992 0.0716 0.0638]
# mixed_state_fraction = 0.5, output_probs = [0.1269 0.6162 0.1311 0.1259]
# mixed_state_fraction = 0.75, output_probs = [0.1885 0.4331 0.1905 0.1879]
# mixed_state_fraction = 1.0, output_probs = [0.25 0.25 0.25 0.25]
# mixed_state_fraction = 0.0, output_probs = [0.0381 0.9504 0.01   0.0016]
# mixed_state_fraction = 0.25, output_probs = [0.0911 0.7753 0.07   0.0637]
# mixed_state_fraction = 0.5, output_probs = [0.144  0.6002 0.13   0.1258]
# mixed_state_fraction = 0.75, output_probs = [0.197  0.4251 0.19   0.1879]
# mixed_state_fraction = 1.0, output_probs = [0.25 0.25 0.25 0.25]
# mixed_state_fraction = 0.0, output_probs = [0.0066 0.9766 0.0066 0.0101]
# mixed_state_fraction = 0.25, output_probs = [0.0675 0.795  0.0675 0.0701]
# mixed_state_fraction = 0.5, output_probs = [0.1283 0.6133 0.1283 0.1301]
# mixed_state_fraction = 0.75, output_probs = [0.1892 0.4317 0.1892 0.19  ]
# mixed_state_fraction = 1.0, output_probs = [0.25 0.25 0.25 0.25]
# mixed_state_fraction = 0.0, output_probs = [0.0023 0.9828 0.001  0.0139]
# mixed_state_fraction = 0.25, output_probs = [0.0642 0.7996 0.0633 0.0729]
# mixed_state_fraction = 0.5, output_probs = [0.1261 0.6164 0.1255 0.1319]
# mixed_state_fraction = 0.75, output_probs = [0.1881 0.4332 0.1878 0.191 ]
# mixed_state_fraction = 1.0, output_probs = [0.25 0.25 0.25 0.25]
# mixed_state_fraction = 0.0, output_probs = [1.090e-02 9.802e-01 8.000e-04 8.100e-03]
# mixed_state_fraction = 0.25, output_probs = [0.0707 0.7976 0.0631 0.0686]
# mixed_state_fraction = 0.5, output_probs = [0.1305 0.6151 0.1254 0.1291]
# mixed_state_fraction = 0.75, output_probs = [0.1902 0.4325 0.1877 0.1895]
# mixed_state_fraction = 1.0, output_probs = [0.25 0.25 0.25 0.25]
# mixed_state_fraction = 0.0, output_probs = [0.0026 0.9838 0.0104 0.0032]
# mixed_state_fraction = 0.25, output_probs = [0.0645 0.8003 0.0703 0.0649]
# mixed_state_fraction = 0.5, output_probs = [0.1263 0.6169 0.1302 0.1266]
# mixed_state_fraction = 0.75, output_probs = [0.1882 0.4334 0.1901 0.1883]
# mixed_state_fraction = 1.0, output_probs = [0.25 0.25 0.25 0.25]
# mixed_state_fraction = 0.0, output_probs = [2.900e-03 9.601e-01 7.000e-04 3.620e-02]
# mixed_state_fraction = 0.25, output_probs = [0.0647 0.7826 0.063  0.0897]
# mixed_state_fraction = 0.5, output_probs = [0.1265 0.6051 0.1254 0.1431]
# mixed_state_fraction = 0.75, output_probs = [0.1882 0.4275 0.1877 0.1966]
# mixed_state_fraction = 1.0, output_probs = [0.25 0.25 0.25 0.25]
# mixed_state_fraction = 0.0, output_probs = [4.000e-04 9.808e-01 9.800e-03 9.000e-03]
# mixed_state_fraction = 0.25, output_probs = [0.0628 0.7981 0.0699 0.0692]
# mixed_state_fraction = 0.5, output_probs = [0.1252 0.6154 0.1299 0.1295]
# mixed_state_fraction = 0.75, output_probs = [0.1876 0.4327 0.19   0.1897]
# mixed_state_fraction = 1.0, output_probs = [0.25 0.25 0.25 0.25]
# mixed_state_fraction = 0.0, output_probs = [5.600e-03 9.824e-01 1.140e-02 6.000e-04]
# mixed_state_fraction = 0.25, output_probs = [0.0667 0.7993 0.071  0.0629]
# mixed_state_fraction = 0.5, output_probs = [0.1278 0.6162 0.1307 0.1253]
# mixed_state_fraction = 0.75, output_probs = [0.1889 0.4331 0.1903 0.1876]
# mixed_state_fraction = 1.0, output_probs = [0.25 0.25 0.25 0.25]
# mixed_state_fraction = 0.0, output_probs = [8.500e-03 9.854e-01 5.900e-03 2.000e-04]
# mixed_state_fraction = 0.25, output_probs = [0.0689 0.8015 0.0669 0.0626]
# mixed_state_fraction = 0.5, output_probs = [0.1293 0.6177 0.1279 0.1251]
# mixed_state_fraction = 0.75, output_probs = [0.1896 0.4338 0.189  0.1875]
# mixed_state_fraction = 1.0, output_probs = [0.25 0.25 0.25 0.25]
# mixed_state_fraction = 0.0, output_probs = [0.0056 0.9806 0.0099 0.004 ]
# mixed_state_fraction = 0.25, output_probs = [0.0667 0.7979 0.0699 0.0655]
# mixed_state_fraction = 0.5, output_probs = [0.1278 0.6153 0.13   0.127 ]
# mixed_state_fraction = 0.75, output_probs = [0.1889 0.4326 0.19   0.1885]
# mixed_state_fraction = 1.0, output_probs = [0.25 0.25 0.25 0.25]
# mixed_state_fraction = 0.0, output_probs = [0.0041 0.9719 0.0156 0.0084]
# mixed_state_fraction = 0.25, output_probs = [0.0656 0.7914 0.0742 0.0688]
# mixed_state_fraction = 0.5, output_probs = [0.1271 0.6109 0.1328 0.1292]
# mixed_state_fraction = 0.75, output_probs = [0.1885 0.4305 0.1914 0.1896]
# mixed_state_fraction = 1.0, output_probs = [0.25 0.25 0.25 0.25]
# mixed_state_fraction = 0.0, output_probs = [0.0012 0.9679 0.0206 0.0104]
# mixed_state_fraction = 0.25, output_probs = [0.0634 0.7884 0.0779 0.0703]
# mixed_state_fraction = 0.5, output_probs = [0.1256 0.6089 0.1353 0.1302]
# mixed_state_fraction = 0.75, output_probs = [0.1878 0.4295 0.1926 0.1901]
# mixed_state_fraction = 1.0, output_probs = [0.25 0.25 0.25 0.25]

# %%
plt.figure(figsize=(6, 4))

for i, mixed_state_fraction in enumerate(mixed_state_fraction_list):
    plt.scatter(
        rav_x_data[0][mixed_state_fraction],
        rav_y_data[0][mixed_state_fraction],
        s=1, label=f'mixed state fraction = {mixed_state_fraction}')
    
plt.ylim(-0.6, 1.6)
plt.xscale('log')
plt.xlabel('# shots')
plt.ylabel('success rate (scaled to decay to 0)')
plt.title(f'{num_system_qubits}-qubit RAV')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
rav_std_data = {}
for seq_idx, rav_result in enumerate(rav_results):
    rav_std_data[seq_idx] = {}
    for i, mixed_state_fraction in enumerate(mixed_state_fraction_list):
        rav_std_data[seq_idx][mixed_state_fraction] = []    
        for n_shots in n_shots_list:
            current_slice = np.array(rav_x_data[seq_idx][mixed_state_fraction]) == n_shots
            y_vals = np.extract(current_slice, rav_y_data[seq_idx][mixed_state_fraction])
            rav_std_data[seq_idx][mixed_state_fraction].append(np.std(y_vals))

# %%
plt.figure(figsize=(6, 4))

for i, mixed_state_fraction in enumerate(mixed_state_fraction_list):
    y_raw = [rav_std_data[seq_idx][mixed_state_fraction] for seq_idx in rav_std_data]
    plt.errorbar(
        n_shots_list,
        y=np.mean(y_raw, axis=0),
        yerr=np.std(y_raw, axis=0) / np.sqrt(sequence_count),
        marker='.',
        markersize=8, label=f'mixed state fraction = {mixed_state_fraction}',
        linestyle='dotted')

plt.xscale('log')
plt.xlabel('# shots')
plt.ylabel('std deviation of fidelity measurement')
plt.title(f'{num_system_qubits}-qubit RAV')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %% [markdown]
# ## How XEB uncertainty scales with # of shots
#
# - Choose a representative random circuit of same length used above for RAV with ideal output state $\lvert\phi\rangle$
# - Plot a whole bunch of points, x-axis = # shots, y-axis = initial state probability, for:
#    - 100% ideal output state $2^n \cdot \rho = \lvert\phi\rangle\langle\phi\rvert$
#    - 75% ideal output state $2^n \cdot \rho = \frac{3}{4} \lvert\phi\rangle\langle\phi\rvert + \frac{1}{4} I$
#    - 50% ideal output state $2^n \cdot \rho = \frac{1}{2} \lvert\phi\rangle\langle\phi\rvert + \frac{1}{2} I$
#    - 25% ideal output state $2^n \cdot \rho = \frac{1}{4} \lvert\phi\rangle\langle\phi\rvert + \frac{3}{4} I$
#    - completely mixed output state $2^n \cdot \rho = I$

# %%
xeb_results = []
for seq_idx in range(sequence_count):
    xeb_layer_count = rav_results[seq_idx].compiled_sequence.get_length() // int(sum(list(unitary_primitive_counts.values())))

    xeb_result = Verification.generate_layered_rav_sequence(
        system_dimension,
        unitary_primitive_counts,
        xeb_layer_count,
        max_step_count = 0,
        threshold = 0.0,
    )

    product = xeb_result.compiled_sequence.product()
    identity = Unitary.identity(system_dimension)
    final_cost = product.distance_from(identity)

    print(f"generated XEB circuit: length {xeb_result.compiled_sequence.get_length()} with final cost {final_cost}")

    xeb_results.append(xeb_result)

    filename = f'{directory}/xeb_{num_system_qubits}q_{xeb_layer_count}_{seq_idx}.txt'
    with open(filename, 'w') as f:
        f.write(f'''
    from qscout.v1.std usepulses *
    register q[{len(qubits_to_use)}]
    prepare_all
    ''')
        f.write(xeb_result.compiled_sequence.get_jaqal())
        f.write(f'''
    measure_all
    ''')

    print(f"SUCCESS: wrote JAQAL circuit to {filename}")
# Out:
# generated XEB circuit: length 98 with final cost 0.1585519550208485
# SUCCESS: wrote JAQAL circuit to output_ideal_rav_vs_xeb_simulations/20220417_131316/xeb_2q_14_0.txt
# generated XEB circuit: length 105 with final cost 0.3868364637085183
# SUCCESS: wrote JAQAL circuit to output_ideal_rav_vs_xeb_simulations/20220417_131316/xeb_2q_15_1.txt
# generated XEB circuit: length 126 with final cost 0.4689377913574365
# SUCCESS: wrote JAQAL circuit to output_ideal_rav_vs_xeb_simulations/20220417_131316/xeb_2q_18_2.txt
# generated XEB circuit: length 245 with final cost 0.5930015790743721
# SUCCESS: wrote JAQAL circuit to output_ideal_rav_vs_xeb_simulations/20220417_131316/xeb_2q_35_3.txt
# generated XEB circuit: length 210 with final cost 0.46203368583587545
# SUCCESS: wrote JAQAL circuit to output_ideal_rav_vs_xeb_simulations/20220417_131316/xeb_2q_30_4.txt
# generated XEB circuit: length 217 with final cost 0.6454928266041674
# SUCCESS: wrote JAQAL circuit to output_ideal_rav_vs_xeb_simulations/20220417_131316/xeb_2q_31_5.txt
# generated XEB circuit: length 112 with final cost 0.30662998229944105
# SUCCESS: wrote JAQAL circuit to output_ideal_rav_vs_xeb_simulations/20220417_131316/xeb_2q_16_6.txt
# generated XEB circuit: length 119 with final cost 0.38244868644441754
# SUCCESS: wrote JAQAL circuit to output_ideal_rav_vs_xeb_simulations/20220417_131316/xeb_2q_17_7.txt
# generated XEB circuit: length 182 with final cost 0.21401126555389205
# SUCCESS: wrote JAQAL circuit to output_ideal_rav_vs_xeb_simulations/20220417_131316/xeb_2q_26_8.txt
# generated XEB circuit: length 161 with final cost 0.3550445230365624
# SUCCESS: wrote JAQAL circuit to output_ideal_rav_vs_xeb_simulations/20220417_131316/xeb_2q_23_9.txt
# generated XEB circuit: length 238 with final cost 0.563455215907737
# SUCCESS: wrote JAQAL circuit to output_ideal_rav_vs_xeb_simulations/20220417_131316/xeb_2q_34_10.txt
# generated XEB circuit: length 266 with final cost 0.41658642702538495
# SUCCESS: wrote JAQAL circuit to output_ideal_rav_vs_xeb_simulations/20220417_131316/xeb_2q_38_11.txt
# generated XEB circuit: length 119 with final cost 0.2627587810894819
# SUCCESS: wrote JAQAL circuit to output_ideal_rav_vs_xeb_simulations/20220417_131316/xeb_2q_17_12.txt
# generated XEB circuit: length 119 with final cost 0.289383329243208
# SUCCESS: wrote JAQAL circuit to output_ideal_rav_vs_xeb_simulations/20220417_131316/xeb_2q_17_13.txt
# generated XEB circuit: length 161 with final cost 0.7796770937564258
# SUCCESS: wrote JAQAL circuit to output_ideal_rav_vs_xeb_simulations/20220417_131316/xeb_2q_23_14.txt
# generated XEB circuit: length 154 with final cost 0.31165987753758206
# SUCCESS: wrote JAQAL circuit to output_ideal_rav_vs_xeb_simulations/20220417_131316/xeb_2q_22_15.txt
# generated XEB circuit: length 91 with final cost 0.07959038094355564
# SUCCESS: wrote JAQAL circuit to output_ideal_rav_vs_xeb_simulations/20220417_131316/xeb_2q_13_16.txt
# generated XEB circuit: length 126 with final cost 0.6407464059374884
# SUCCESS: wrote JAQAL circuit to output_ideal_rav_vs_xeb_simulations/20220417_131316/xeb_2q_18_17.txt
# generated XEB circuit: length 98 with final cost 0.42073131250192086
# SUCCESS: wrote JAQAL circuit to output_ideal_rav_vs_xeb_simulations/20220417_131316/xeb_2q_14_18.txt
# generated XEB circuit: length 273 with final cost 0.21283812736167984
# SUCCESS: wrote JAQAL circuit to output_ideal_rav_vs_xeb_simulations/20220417_131316/xeb_2q_39_19.txt

# %%
xeb_x_data = {}
xeb_y_data = {}    
for seq_idx, xeb_result in enumerate(xeb_results):
    xeb_sequence_matrix = xeb_result.compiled_sequence.product().get_matrix()

    mixed_state_fraction_list = [0.0, 0.25, 0.5, 0.75, 1.0]

    xeb_x_data[seq_idx] = {}
    xeb_y_data[seq_idx] = {}

    for i, mixed_state_fraction in enumerate(mixed_state_fraction_list):
        initial_state_index = 1

        # calculate the ideal output state
        initial_state = np.zeros(system_dimension)
        initial_state[initial_state_index] = 1
        initial_state = np.atleast_2d(initial_state).T
        ideal_output_state = xeb_sequence_matrix @ initial_state
        #print("ideal_output_state coefficients:", np.round(ideal_output_state.T, 4))

        # validate the state
        ideal_output_probs = np.array([np.linalg.norm(c)**2 for c in ideal_output_state])
        #print("ideal_output_probs =", np.round(ideal_output_probs, 4))
        sum_of_probs = np.sum([np.linalg.norm(c)**2 for c in ideal_output_state])
        assert np.isclose(sum_of_probs, 1.0)

        # mix in the mixed state fraction
        mixed_state_output_probs = np.array([1/system_dimension for _ in range(system_dimension)])
        output_probs = np.add(
            (1-mixed_state_fraction) * ideal_output_probs,
            mixed_state_fraction * mixed_state_output_probs
        )
        print(f"mixed_state_fraction = {mixed_state_fraction}, output_probs = {np.round(output_probs, 4)}")

        # sample many times and plot
        n_shots_list = [25, 50, 100, 200, 400, 800, 1600, 3200, 6400]
        repetitions = 100
        xeb_x_data[seq_idx][mixed_state_fraction] = []
        xeb_y_data[seq_idx][mixed_state_fraction] = []
        for n_shots in n_shots_list:
            for _ in range(repetitions):
                measurements = [int(np.random.random() < output_probs[initial_state_index]) for _ in range(n_shots)]
                measurements = np.random.choice(system_dimension, size=n_shots, p=output_probs)
                measurement_probs = [np.count_nonzero(measurements == k) / n_shots for k in range(system_dimension)]
                assert np.isclose(np.sum(measurement_probs), 1.0)

                # calculate cross-entropy fidelity between ideal_output_probs, measurement_probs
                e_u = np.sum(ideal_output_probs**2)
                u_u = np.sum(ideal_output_probs) / system_dimension
                m_u = np.sum(ideal_output_probs * measurement_probs)
                y = m_u - u_u
                x = e_u - u_u
                fidelity = (x * y) / (x ** 2)

                xeb_x_data[seq_idx][mixed_state_fraction].append(n_shots)
                xeb_y_data[seq_idx][mixed_state_fraction].append(fidelity)
# Out:
# mixed_state_fraction = 0.0, output_probs = [0.0092 0.7734 0.0321 0.1853]
# mixed_state_fraction = 0.25, output_probs = [0.0694 0.6426 0.0866 0.2014]
# mixed_state_fraction = 0.5, output_probs = [0.1296 0.5117 0.1411 0.2176]
# mixed_state_fraction = 0.75, output_probs = [0.1898 0.3809 0.1955 0.2338]
# mixed_state_fraction = 1.0, output_probs = [0.25 0.25 0.25 0.25]
# mixed_state_fraction = 0.0, output_probs = [0.1683 0.6912 0.132  0.0086]
# mixed_state_fraction = 0.25, output_probs = [0.1887 0.5809 0.1615 0.069 ]
# mixed_state_fraction = 0.5, output_probs = [0.2091 0.4706 0.191  0.1293]
# mixed_state_fraction = 0.75, output_probs = [0.2296 0.3603 0.2205 0.1897]
# mixed_state_fraction = 1.0, output_probs = [0.25 0.25 0.25 0.25]
# mixed_state_fraction = 0.0, output_probs = [0.0137 0.8011 0.0983 0.0868]
# mixed_state_fraction = 0.25, output_probs = [0.0728 0.6634 0.1362 0.1276]
# mixed_state_fraction = 0.5, output_probs = [0.1319 0.5256 0.1742 0.1684]
# mixed_state_fraction = 0.75, output_probs = [0.1909 0.3878 0.2121 0.2092]
# mixed_state_fraction = 1.0, output_probs = [0.25 0.25 0.25 0.25]
# mixed_state_fraction = 0.0, output_probs = [0.6867 0.1193 0.0129 0.1811]
# mixed_state_fraction = 0.25, output_probs = [0.5775 0.152  0.0722 0.1983]
# mixed_state_fraction = 0.5, output_probs = [0.4684 0.1847 0.1315 0.2155]
# mixed_state_fraction = 0.75, output_probs = [0.3592 0.2173 0.1907 0.2328]
# mixed_state_fraction = 1.0, output_probs = [0.25 0.25 0.25 0.25]
# mixed_state_fraction = 0.0, output_probs = [0.2587 0.3823 0.0779 0.2811]
# mixed_state_fraction = 0.25, output_probs = [0.2565 0.3492 0.121  0.2733]
# mixed_state_fraction = 0.5, output_probs = [0.2543 0.3161 0.164  0.2656]
# mixed_state_fraction = 0.75, output_probs = [0.2522 0.2831 0.207  0.2578]
# mixed_state_fraction = 1.0, output_probs = [0.25 0.25 0.25 0.25]
# mixed_state_fraction = 0.0, output_probs = [0.39   0.5036 0.0896 0.0169]
# mixed_state_fraction = 0.25, output_probs = [0.355  0.4402 0.1297 0.0752]
# mixed_state_fraction = 0.5, output_probs = [0.32   0.3768 0.1698 0.1334]
# mixed_state_fraction = 0.75, output_probs = [0.285  0.3134 0.2099 0.1917]
# mixed_state_fraction = 1.0, output_probs = [0.25 0.25 0.25 0.25]
# mixed_state_fraction = 0.0, output_probs = [0.1493 0.4628 0.3383 0.0496]
# mixed_state_fraction = 0.25, output_probs = [0.1745 0.4096 0.3162 0.0997]
# mixed_state_fraction = 0.5, output_probs = [0.1997 0.3564 0.2942 0.1498]
# mixed_state_fraction = 0.75, output_probs = [0.2248 0.3032 0.2721 0.1999]
# mixed_state_fraction = 1.0, output_probs = [0.25 0.25 0.25 0.25]
# mixed_state_fraction = 0.0, output_probs = [0.2555 0.5912 0.0908 0.0625]
# mixed_state_fraction = 0.25, output_probs = [0.2542 0.5059 0.1306 0.1094]
# mixed_state_fraction = 0.5, output_probs = [0.2528 0.4206 0.1704 0.1562]
# mixed_state_fraction = 0.75, output_probs = [0.2514 0.3353 0.2102 0.2031]
# mixed_state_fraction = 1.0, output_probs = [0.25 0.25 0.25 0.25]
# mixed_state_fraction = 0.0, output_probs = [0.004  0.7879 0.1467 0.0615]
# mixed_state_fraction = 0.25, output_probs = [0.0655 0.6534 0.1725 0.1086]
# mixed_state_fraction = 0.5, output_probs = [0.127  0.5189 0.1983 0.1558]
# mixed_state_fraction = 0.75, output_probs = [0.1885 0.3845 0.2242 0.2029]
# mixed_state_fraction = 1.0, output_probs = [0.25 0.25 0.25 0.25]
# mixed_state_fraction = 0.0, output_probs = [0.0301 0.7982 0.0048 0.1669]
# mixed_state_fraction = 0.25, output_probs = [0.0851 0.6612 0.0661 0.1876]
# mixed_state_fraction = 0.5, output_probs = [0.14   0.5241 0.1274 0.2084]
# mixed_state_fraction = 0.75, output_probs = [0.195  0.3871 0.1887 0.2292]
# mixed_state_fraction = 1.0, output_probs = [0.25 0.25 0.25 0.25]
# mixed_state_fraction = 0.0, output_probs = [0.1066 0.5342 0.0613 0.298 ]
# mixed_state_fraction = 0.25, output_probs = [0.1424 0.4631 0.1085 0.286 ]
# mixed_state_fraction = 0.5, output_probs = [0.1783 0.3921 0.1556 0.274 ]
# mixed_state_fraction = 0.75, output_probs = [0.2141 0.321  0.2028 0.262 ]
# mixed_state_fraction = 1.0, output_probs = [0.25 0.25 0.25 0.25]
# mixed_state_fraction = 0.0, output_probs = [0.2718 0.4288 0.243  0.0564]
# mixed_state_fraction = 0.25, output_probs = [0.2663 0.3841 0.2448 0.1048]
# mixed_state_fraction = 0.5, output_probs = [0.2609 0.3394 0.2465 0.1532]
# mixed_state_fraction = 0.75, output_probs = [0.2554 0.2947 0.2483 0.2016]
# mixed_state_fraction = 1.0, output_probs = [0.25 0.25 0.25 0.25]
# mixed_state_fraction = 0.0, output_probs = [0.1872 0.6916 0.0578 0.0634]
# mixed_state_fraction = 0.25, output_probs = [0.2029 0.5812 0.1058 0.11  ]
# mixed_state_fraction = 0.5, output_probs = [0.2186 0.4708 0.1539 0.1567]
# mixed_state_fraction = 0.75, output_probs = [0.2343 0.3604 0.2019 0.2033]
# mixed_state_fraction = 1.0, output_probs = [0.25 0.25 0.25 0.25]
# mixed_state_fraction = 0.0, output_probs = [0.0815 0.4731 0.3093 0.1361]
# mixed_state_fraction = 0.25, output_probs = [0.1236 0.4173 0.2945 0.1646]
# mixed_state_fraction = 0.5, output_probs = [0.1658 0.3615 0.2797 0.1931]
# mixed_state_fraction = 0.75, output_probs = [0.2079 0.3058 0.2648 0.2215]
# mixed_state_fraction = 1.0, output_probs = [0.25 0.25 0.25 0.25]
# mixed_state_fraction = 0.0, output_probs = [0.6143 0.2028 0.1733 0.0096]
# mixed_state_fraction = 0.25, output_probs = [0.5232 0.2146 0.1925 0.0697]
# mixed_state_fraction = 0.5, output_probs = [0.4321 0.2264 0.2117 0.1298]
# mixed_state_fraction = 0.75, output_probs = [0.3411 0.2382 0.2308 0.1899]
# mixed_state_fraction = 1.0, output_probs = [0.25 0.25 0.25 0.25]
# mixed_state_fraction = 0.0, output_probs = [0.0548 0.7529 0.0805 0.1118]
# mixed_state_fraction = 0.25, output_probs = [0.1036 0.6272 0.1229 0.1463]
# mixed_state_fraction = 0.5, output_probs = [0.1524 0.5015 0.1653 0.1809]
# mixed_state_fraction = 0.75, output_probs = [0.2012 0.3757 0.2076 0.2154]
# mixed_state_fraction = 1.0, output_probs = [0.25 0.25 0.25 0.25]
# mixed_state_fraction = 0.0, output_probs = [0.093  0.8954 0.0033 0.0083]
# mixed_state_fraction = 0.25, output_probs = [0.1322 0.734  0.065  0.0687]
# mixed_state_fraction = 0.5, output_probs = [0.1715 0.5727 0.1267 0.1291]
# mixed_state_fraction = 0.75, output_probs = [0.2107 0.4113 0.1883 0.1896]
# mixed_state_fraction = 1.0, output_probs = [0.25 0.25 0.25 0.25]
# mixed_state_fraction = 0.0, output_probs = [0.0139 0.8946 0.03   0.0616]
# mixed_state_fraction = 0.25, output_probs = [0.0729 0.7334 0.085  0.1087]
# mixed_state_fraction = 0.5, output_probs = [0.1319 0.5723 0.14   0.1558]
# mixed_state_fraction = 0.75, output_probs = [0.191  0.4111 0.195  0.2029]
# mixed_state_fraction = 1.0, output_probs = [0.25 0.25 0.25 0.25]
# mixed_state_fraction = 0.0, output_probs = [3.353e-01 6.080e-01 3.000e-04 5.640e-02]
# mixed_state_fraction = 0.25, output_probs = [0.314  0.5185 0.0627 0.1048]
# mixed_state_fraction = 0.5, output_probs = [0.2926 0.429  0.1251 0.1532]
# mixed_state_fraction = 0.75, output_probs = [0.2713 0.3395 0.1876 0.2016]
# mixed_state_fraction = 1.0, output_probs = [0.25 0.25 0.25 0.25]
# mixed_state_fraction = 0.0, output_probs = [0.0522 0.7145 0.1907 0.0426]
# mixed_state_fraction = 0.25, output_probs = [0.1016 0.5984 0.2055 0.0945]
# mixed_state_fraction = 0.5, output_probs = [0.1511 0.4823 0.2204 0.1463]
# mixed_state_fraction = 0.75, output_probs = [0.2005 0.3661 0.2352 0.1982]
# mixed_state_fraction = 1.0, output_probs = [0.25 0.25 0.25 0.25]

# %%
plt.figure(figsize=(6, 4))

for i, mixed_state_fraction in enumerate(mixed_state_fraction_list):
    plt.scatter(
        xeb_x_data[0][mixed_state_fraction],
        xeb_y_data[0][mixed_state_fraction],
        s=1, label=f'mixed state fraction = {mixed_state_fraction}')

plt.ylim(-0.6, 1.6)
plt.xscale('log')
plt.xlabel('# shots')
plt.ylabel('cross-entropy fidelity')
plt.title(f'{num_system_qubits}-qubit XEB')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
xeb_std_data = {}
for seq_idx, xeb_result in enumerate(xeb_results):
    xeb_std_data[seq_idx] = {}
    for i, mixed_state_fraction in enumerate(mixed_state_fraction_list):
        xeb_std_data[seq_idx][mixed_state_fraction] = []    
        for n_shots in n_shots_list:
            current_slice = np.array(xeb_x_data[seq_idx][mixed_state_fraction]) == n_shots
            y_vals = np.extract(current_slice, xeb_y_data[seq_idx][mixed_state_fraction])
            xeb_std_data[seq_idx][mixed_state_fraction].append(np.std(y_vals))

# %%
plt.figure(figsize=(6, 4))

for i, mixed_state_fraction in enumerate(mixed_state_fraction_list):
    y_raw = [xeb_std_data[seq_idx][mixed_state_fraction] for seq_idx in xeb_std_data]
    plt.errorbar(
        n_shots_list,
        y=np.mean(y_raw, axis=0),
        yerr=np.std(y_raw, axis=0) / np.sqrt(sequence_count),
        marker='.',
        markersize=8, label=f'mixed state fraction = {mixed_state_fraction}',
        linestyle='dotted')

plt.xscale('log')
plt.xlabel('# shots')
plt.ylabel('std deviation of fidelity measurement')
plt.title(f'{num_system_qubits}-qubit XEB')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %%
save_data = {
    "mixed_state_fraction_list": mixed_state_fraction_list,
    "n_shots_list": n_shots_list,
    "rav_x_data": rav_x_data,
    "rav_y_data": rav_y_data,
    "rav_std_data": rav_std_data,
    "xeb_x_data": xeb_x_data,
    "xeb_y_data": xeb_y_data,
    "xeb_std_data": xeb_std_data,
}
pickleslicer.dump(save_data, f'{directory}/ideal_rav_vs_xeb_simulations_{num_system_qubits}q.pickle')
print(f'Saved to {directory}/ideal_rav_vs_xeb_simulations_{num_system_qubits}q.pickle')
# Out:
# Saved to output_ideal_rav_vs_xeb_simulations/20220417_131316/ideal_rav_vs_xeb_simulations_2q.pickle

# %%
directory = 'output_ideal_rav_vs_xeb_simulations/20220417_131316'
load_data = pickleslicer.load(f'{directory}/ideal_rav_vs_xeb_simulations_{num_system_qubits}q.pickle')
mixed_state_fraction_list = load_data["mixed_state_fraction_list"]
n_shots_list = load_data["n_shots_list"]
rav_x_data = load_data["rav_x_data"]
rav_y_data = load_data["rav_y_data"]
rav_std_data = load_data["rav_std_data"]
xeb_x_data = load_data["xeb_x_data"]
xeb_y_data = load_data["xeb_y_data"]
xeb_std_data = load_data["xeb_std_data"]
